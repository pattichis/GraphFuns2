# %% [markdown]
# # Setup

# %% [markdown]
# The following code sets up the system by downloading the library from the web.

# %%
# Remove existing files
import os

# Install old Kaleido that works
# !pip install -U plotly>=6.1.1
# !pip install -U kaleido
# !kaleido_get_chrome # Install Chrome for Kaleido

print('Installing missing Kaleido dependencies...')
# !sudo apt update && sudo apt-get install libnss3 libatk-bridge2.0-0 libcups2 libxcomposite1 libxdamage1 libxfixes3 libxrandr2 libgbm1 libxkbcommon0 libpango-1.0-0 libcairo2 libasound2
print('Kaleido dependencies installation complete.')

import importlib
import plotly
importlib.reload(plotly)

import plotly.express as px

try:
  fig = px.line(x=[1,2,3], y=[1,4,9], title="Colab Plot")
  fig.write_image("plot.png")
except:
  str = input("Click on Restart Session")



os.chdir("/content/")
#!find './' -maxdepth 1 -type f -delete

# Mount the drive:
from google.colab import drive
drive.mount('/content/drive')

# Download the lineart library
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/lineart_v3.py

# Download the symbolic graphs library.
# !wget 'https://raw.githubusercontent.com/pattichis/GraphFuns2/main/symbolic_graphs2.py'


# Import functions for creating videos
from lineart_v3 import table, simulationVideo, textImage, plotTablesLines, CreateVideo, changeVideoSpeed

# Import symbolic plotting functions
from symbolic_graphs2 import graph_funs
import numpy as np

# Import the library:
import sympy as sp

from sympy import symbols, Eq

from sympy.interactive.printing import init_printing
init_printing()
# Out:
# Requirement already satisfied: kaleido in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Requirement already satisfied: choreographer>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from kaleido) (1.3.0)
# Requirement already satisfied: logistro>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from kaleido) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.12/dist-packages (from kaleido) (3.11.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaleido) (26.2)
# Requirement already satisfied: platformdirs>=4.3.6 in /usr/local/lib/python3.12/dist-packages (from choreographer>=1.3.0->kaleido) (4.10.0)
# Requirement already satisfied: simplejson>=3.19.3 in /usr/local/lib/python3.12/dist-packages (from choreographer>=1.3.0->kaleido) (4.1.1)
# /root/.local/share/choreographer/deps/chrome-linux64/chrome
# Installing missing Kaleido dependencies...
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:7 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 120 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1.2).
# libcairo2 is already the newest version (1.16.0-5ubuntu2.1).
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.21).
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.4).
# libnss3 is already the newest version (2:3.98-0ubuntu0.22.04.4).
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 120 not upgraded.
# Kaleido dependencies installation complete.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File ‘lineart_v3.py’ already there; not retrieving.
#
# --2026-07-27 22:52:00--  https://raw.githubusercontent.com/pattichis/GraphFuns2/main/symbolic_graphs2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16371 (16K) [text/plain]
# Saving to: ‘symbolic_graphs2.py.2’
#
# symbolic_graphs2.py 100%[===================>]  15.99K  --.-KB/s    in 0.001s
#
# 2026-07-27 22:52:00 (17.2 MB/s) - ‘symbolic_graphs2.py.2’ saved [16371/16371]

# %% [markdown]
# # Make a closed figure function
#
# Here is a list of colors:
#    "blue", "green", "red", "cyan", "magenta", "yellow", "black", "white","olive","indigo".

# %%
def make_closed_fig(plot, a, b, h, k, d, num_of_points, color='black'):
  """ Make a closed figure using:
       f(x)=a*b**(x-h)+k
  - a is a constant.
  - b is the base.
  - h is horizontal translation in (x-h).
  - k is vertical translation.
  Here, d is used to determine the domain: from -d to +d.
  num_of_points is the number of points to plot.
  plot specifies the plot object to plot on.
  The image is stored in img.
  """
  # Create the symbol
  x = sp.symbols('x')
  f0 = a*(b)**(x)+k

  # Specify mother function
  # Shift the domain by +h.
  f1 = f0.subs(x, x-h)
  domain1 = [0+h, d+h, num_of_points]

  # Invert it and move it up
  # Same domain.
  # Move f2 up
  f2 = -f1 + 2*f1.subs(x, d+h)
  domain2 = domain1

  # Reflect both:
  f3 = f0.subs(x, -x+h)
  domain3 = [h-d, 0+h, num_of_points]

  f4 = -f0.subs(x, -x+h) + 2*f3.subs(x, -d+h)
  domain4 = domain3

  plot.add_fun(f1, domain1, 'f1(x)='+str(f1), color)
  plot.add_fun(f2, domain2, 'f2(x)='+str(f2), color)
  plot.add_fun(f3, domain3, 'f3(x)='+str(f3), color)
  plot.add_fun(f4, domain4, 'f4(x)='+str(f4), color)

# %% [markdown]
# # Make a video of drawing a face

# %%
b=4
d=5


plot = graph_funs(equal_axes=True, hide_axes=False)

plot.set_XY(minX=-10, maxX=+10, minY=0, maxY=+10)


make_closed_fig(plot, a=6, b=1.1, h=0, k=-5, d=d, num_of_points=20, color ="brown")
make_closed_fig(plot, a=6, b=1.1, h=0, k=-5, d=3, num_of_points=20, color ="tan")
plot.plot_funs(plot_title="face", img_name="frame1.png")


make_closed_fig(plot, a=1, b=2, h=2.7, k=5.5, d=1, num_of_points=20, color="brown")
make_closed_fig(plot, a=1, b=2, h=-2.7, k=5.5, d=1, num_of_points=20, color="brown")
plot.plot_funs(plot_title="ears", img_name="frame2.png")

make_closed_fig(plot, a=1, b=2, h=0, k=0.5, d=1, num_of_points=20, color="#ff5aa4")
plot.plot_funs(plot_title="big nose", img_name="frame3.png")

make_closed_fig(plot, a=1, b=2, h=-2.7, k=5.5, d=.5, num_of_points=20, color="#FF0080")
make_closed_fig(plot, a=1, b=2, h=2.7, k=5.5, d=.5, num_of_points=20, color="#FF0080")
plot.plot_funs(plot_title="small ears", img_name="frame4.png")

make_closed_fig(plot, a=1, b=2, h=2.5, k=3, d=.8, num_of_points=20, color='black')
make_closed_fig(plot, a=1, b=2, h=-2.5, k=3, d=.8, num_of_points=20, color='black')

make_closed_fig(plot, a=1, b=2, h=2.5, k=3, d=.4, num_of_points=20, color="#06402b")
make_closed_fig(plot, a=1, b=2, h=-2.5, k=3, d=.4, num_of_points=20, color="#06402b")

plot.plot_funs(plot_title="eyes", img_name="frame5.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="72c1af88-c15d-4a4d-9762-94b37049c794" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("72c1af88-c15d-4a4d-9762-94b37049c794")) {                    Plotly.newPlot(                        "72c1af88-c15d-4a4d-9762-94b37049c794",                        [{"line":{"color":"brown"},"mode":"lines","name":"f1(x)=6*1.1^x - 5","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAB5DeU1lNfQP3kN5TWU1+A\u002fNpTXUF5D6T95DeU1lNfwP9dQXkN5DfU\u002fNpTXUF5D+T+U11BeQ3n9P3kN5TWU1wBAKK+hvIbyAkDXUF5DeQ0FQIbyGsprKAdANpTXUF5DCUDlNZTXUF4LQJTXUF5DeQ1AQ3kN5TWUD0B5DeU1lNcQQFFeQ3kN5RFAKK+hvIbyEkAAAAAAAAAUQA=="},"y":{"dtype":"f8","bdata":"AAAAAAAA8D\u002f453eJM3DyP5CRBrFB8PQ\u002fdGgyjJGA9z8cGcXOjCH6P8Ct0duf0\u002fw\u002fMFwp1zmX\u002fz8s6qBbZjYBQIz4x6tmqgJAdOCsxdknBEC4doEY\u002fa4FQBJP66IPQAdACAMp\u002fVHbCEBccHljBoEKQFCcxsBwMQxAWPOVudbsDUBAqD+3f7MPQLSAt3nawhBA9Lb2weCxEUCiJF0z+aYSQA=="},"type":"scatter"},{"line":{"color":"brown"},"mode":"lines","name":"f2(x)=14.32612 - 6*1.1^x","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAB5DeU1lNfQP3kN5TWU1+A\u002fNpTXUF5D6T95DeU1lNfwP9dQXkN5DfU\u002fNpTXUF5D+T+U11BeQ3n9P3kN5TWU1wBAKK+hvIbyAkDXUF5DeQ0FQIbyGsprKAdANpTXUF5DCUDlNZTXUF4LQJTXUF5DeQ1AQ3kN5TWUD0B5DeU1lNcQQFFeQ3kN5RFAKK+hvIbyEkAAAAAAAAAUQA=="},"y":{"dtype":"f8","bdata":"oiRdM\u002fmmIECjJy7C8lggQHBSPP3wCCBAJ6+tA85tH0D9Agkzj8UeQNTdxW8KGR5AOPLv8CNoHUAu1Ok4v7IcQP5M1hC\u002f+BtACtnjgwU6G0DojXnac3YaQLuhRJXqrRlAwMclaEngGEAWkf00bw0YQBz7VgY6NRdAmE\u002fvCYdXFkAkdRqLMnQVQJDIAu0XixRAUJLDpBGcE0CiJF0z+aYSQA=="},"type":"scatter"},{"line":{"color":"brown"},"mode":"lines","name":"
6\u002f1.1^x","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAFMAor6G8hvISwFFeQ3kN5RHAeQ3lNZTXEMBEeQ3lNZQPwJTXUF5DeQ3A5TWU11BeC8A2lNdQXkMJwIfyGsprKAfA2FBeQ3kNBcApr6G8hvICwHoN5TWU1wDAlNdQXkN5\u002fb82lNdQXkP5v9hQXkN5DfW\u002feg3lNZTX8L84lNdQXkPpv3gN5TWU1+C\u002fgA3lNZTX0L8AAAAAAAAAAA=="},"y":{"dtype":"f8","bdata":"oiRdM\u002fmmEkD0tvbB4LERQLSAt3nawhBAQKg\u002ft3+zD0BY85W51uwNQFCcxsBwMQxAXHB5YwaBCkAIAyn9UdsIQBJP66IPQAdAuHaBGP2uBUB04KzF2ScEQIz4x6tmqgJALOqgW2Y2AUAwXCnXOZf\u002fP8Ct0duf0\u002fw\u002fHBnFzowh+j90aDKMkYD3P5CRBrFB8PQ\u002fAOh3iTNw8j8AAAAAAADwPw=="},"type":"scatter"},{"line":{"color":"brown"},"mode":"lines","name":"f4(x)=14.32612 - 6\u002f1.1^x","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAFMAor6G8hvISwFFeQ3kN5RHAeQ3lNZTXEMBEeQ3lNZQPwJTXUF5DeQ3A5TWU11BeC8A2lNdQXkMJwIfyGsprKAfA2FBeQ3kNBcApr6G8hvICwHoN5TWU1wDAlNdQXkN5\u002fb82lNdQXkP5v9hQXkN5DfW\u002feg3lNZTX8L84lNdQXkPpv3gN5TWU1+C\u002fgA3lNZTX0L8AAAAAAAAAAA=="},"y":{"dtype":"f8","bdata":"oiRdM\u002fmmEkBQksOkEZwTQJDIAu0XixRAJHUaizJ0FUCYT+8Jh1cWQBz7VgY6NRdAFpH9NG8NGEDAxyVoSeAYQLuhRJXqrRlA6I152nN2GkAK2eODBTobQP5M1hC\u002f+BtALtTpOL+yHEA48u\u002fwI2gdQNTdxW8KGR5A\u002fQIJM4\u002fFHkAnr60Dzm0fQHBSPP3wCCBAoicuwvJYIECiJF0z+aYgQA=="},"type":"scatter"},{"line":{"color":"tan"},"mode":"lines","name":"f1(x)=6*1.1^x - 5","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAABeQ3kN5TXEP15DeQ3lNdQ\u002fDeU1lNdQ3j9eQ3kN5TXkPzaU11BeQ+k\u002fDeU1lNdQ7j\u002fyGsprKK\u002fxP15DeQ3lNfQ\u002fymsor6G89j82lNdQXkP5P6G8hvIayvs\u002fDeU1lNdQ\u002fj+8hvIaymsAQPIaymsorwFAKK+hvIbyAkBeQ3kN5TUEQJTXUF5DeQVAymsor6G8BkAAAAAAAAAIQA=="},"y":{"dtype":"f8","bdata":"AAAAAAAA8D94v2z5o3TxP\u002fCdvmru7vI\u002fBN2sQvVu9D+wOhHFzvT1P3RoMoyRgPc\u002fGIUTilQS+T+grMgJL6r6P2Cy0LA4SPw\u002f5Bh0gIns\u002fT8wXCnXOZf\u002fP5hR\u002fzgxpABAbHYENw6AAUBoZ+ykQF8CQGxtenPVQQNAdOCsxdknBEBQIoDxWhEFQBiOtIBm\u002fgVA\u002fGeXMQrvBkAc2c73U+MHQA=="},"type":"scatter"},{"line":{"color":"tan"},"mode":"lines","name":"f2(x)=10.972 - 6*1.1^x","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAABeQ3kN5TXEP15DeQ3lNdQ\u002fDeU1lN ...

# %% [markdown]
# # Make the drawing video
#
# 1. List all of the frames in img_list.
# 2. Give the duration in seconds how long you want each frame to appear.
# 3. Make your video.

# %%
# Create a video

# Decide which images and videos you want to put together:
img_list = ["frame1.png", "frame2.png","frame3.png","frame4.png","frame5.png"]

# Set the duration for each one in seconds.
durations_list = [2.0,   # duration for frame1.png
                  1.0, 1.0, 1.0, 1.0]   # duration for frame2.png

# Create the video:
video=CreateVideo(video_name="all.mp4",       # This is file name of the final video.
                  file_list=img_list,         # This the list of images and files to combine.
                  fps=10,                     # The number of frames per second.
                  durations=durations_list)   # The duration for each one.

# Display the video:
video.ipython_display()
# Out:
# Opening  frame1.png
# Opening  frame2.png
# Opening  frame3.png
# Opening  frame4.png
# Opening  frame5.png
# video: height =  500  width =  700
# File 'all.mp4' has been removed.
# VideoWriter initialized successfully.
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
