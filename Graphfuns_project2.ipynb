# %% [markdown]
# <a href="https://colab.research.google.com/github/pattichis/GraphFuns2/blob/main/Graphfuns_project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# The following code sets up the system by downloading the library from the web.

# %%
# Remove existing files
import os

# Install old Kaleido that works
# !pip uninstall -y kaleido
# !pip install -q kaleido==0.2.1

import importlib
import plotly
importlib.reload(plotly)

import plotly.express as px

try:
  fig = px.line(x=[1,2,3], y=[1,4,9], title="Colab Plot")
  fig.write_image("plot.png")
except:
  str = input("Click on Restart Session")



os.chdir("/content/")
#!find './' -maxdepth 1 -type f -delete

# Mount the drive:
from google.colab import drive
drive.mount('/content/drive')

# Download the lineart library
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/lineart_v3.py

# Download the symbolic graphs library.
# !wget 'https://raw.githubusercontent.com/pattichis/GraphFuns2/main/symbolic_graphs2.py'


# Import functions for creating videos
from lineart_v3 import table, simulationVideo, textImage, plotTablesLines, CreateVideo, changeVideoSpeed

# Import symbolic plotting functions
from symbolic_graphs2 import graph_funs
import numpy as np

# Import the library:
import sympy as sp

from sympy import symbols, Eq

from sympy.interactive.printing import init_printing
init_printing()
# Out:
# WARNING: Skipping kaleido as it is not installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.6 MB/s eta 0:00:00
# Mounted at /content/drive
# --2026-04-17 13:07:23--  https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/lineart_v3.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30381 (30K) [text/plain]
# Saving to: ‘lineart_v3.py’
#
# lineart_v3.py       100%[===================>]  29.67K  --.-KB/s    in 0.003s
#
# 2026-04-17 13:07:23 (9.79 MB/s) - ‘lineart_v3.py’ saved [30381/30381]
#
# --2026-04-17 13:07:23--  https://raw.githubusercontent.com/pattichis/GraphFuns2/main/symbolic_graphs2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# ...

# %% [markdown]
# # Make a closed figure function
#
# Here is a list of colors:
#    "blue", "green", "red", "cyan", "magenta", "yellow", "black", "white","olive","indigo".

# %%
def make_closed_fig(plot, a, b, h, k, d, num_of_points):
  """ Make a closed figure using:
       f(x)=a*b**(x-h)+k
  - a is a constant.
  - b is the base.
  - h is horizontal translation in (x-h).
  - k is vertical translation.
  Here, d is used to determine the domain: from -d to +d.
  num_of_points is the number of points to plot.
  plot specifies the plot object to plot on.
  The image is stored in img.
  """
  # Create the symbol
  x = sp.symbols('x')
  f0 = a*(b)**(x)+k

  # Specify mother function
  # Shift the domain by +h.
  f1 = f0.subs(x, x-h)
  domain1 = [0+h, d+h, num_of_points]

  # Invert it and move it up
  # Same domain.
  # Move f2 up
  f2 = -f1 + 2*f1.subs(x, d+h)
  domain2 = domain1

  # Reflect both:
  f3 = f0.subs(x, -x+h)
  domain3 = [h-d, 0+h, num_of_points]

  f4 = -f0.subs(x, -x+h) + 2*f3.subs(x, -d+h)
  domain4 = domain3

  plot.add_fun(f1, domain1, 'f1(x)='+str(f1), 'red')
  plot.add_fun(f2, domain2, 'f2(x)='+str(f2), 'blue')
  plot.add_fun(f3, domain3, 'f3(x)='+str(f3), 'green')
  plot.add_fun(f4, domain4, 'f4(x)='+str(f4), 'orange')

# %% [markdown]
# # Move things around

# %%
# Placing closed figures everywhere!

# Create a graph object with equal_axes)
plot = graph_funs(equal_axes=True, hide_axes=False)

# Setup the grid
# Determine the range for X based on reflections and translations.
# Determine the range for Y based on reflections and translations (look at maximum values).
plot.set_XY(minX=0, maxX=+25, minY=0, maxY=+25)

# Arithmetic series for x:
start_x = 5
stop_x  = 25
step_x  = 5

# Arithmetic series for y:
start_y = 5
stop_y  = 25
step_y  = 5

for x in range(start_x, stop_x, step_x):
  for y in range(start_y, stop_y, step_y):
    make_closed_fig(plot, a=6, b=1.1, h=x, k=y, d=1, num_of_points=20)

plot.plot_funs(plot_title="Moving things around", img_name="frame1.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Varying the domain

# %%
# Playing with the domain

# Create a graph object with equal_axes)
plot = graph_funs(equal_axes=True, hide_axes=False)

# Setup the grid
# Determine the range for X based on reflections and translations.
# Determine the range for Y based on reflections and translations (look at maximum values).
plot.set_XY(minX=-10, maxX=+10, minY=0, maxY=+100)

# Arithmetic series for x:
start_d = 5
stop_d  = 25
step_d  = 5

for d in range(start_d, stop_d, step_d):
  make_closed_fig(plot, a=6, b=1.1, h=0, k=0, d=d, num_of_points=20)

plot.plot_funs(plot_title="Playing with the domain", img_name="frame1.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Varying the constant a

# %%
# Playing with the domain

# Create a graph object with equal_axes)
plot = graph_funs(equal_axes=True, hide_axes=False)

# Setup the grid
# Determine the range for X based on reflections and translations.
# Determine the range for Y based on reflections and translations (look at maximum values).
plot.set_XY(minX=-10, maxX=+10, minY=0, maxY=+100)

# Arithmetic series for x:
min_a = 0.5
max_a  = 5
num_of_points = 5

for a in np.linspace(min_a, max_a, num_of_points):
  make_closed_fig(plot, a=a, b=1.1, h=0, k=0, d=20, num_of_points=20)

plot.plot_funs(plot_title="Playing with a", img_name="frame1.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Varying the base b

# %%
# Playing with b

# Create a graph object with equal_axes)
plot = graph_funs(equal_axes=True, hide_axes=False)

# Setup the grid
# Determine the range for X based on reflections and translations.
# Determine the range for Y based on reflections and translations (look at maximum values).
plot.set_XY(minX=-10, maxX=+10, minY=0, maxY=+40)

# Arithmetic series for x:
start_b = 1
stop_b  = 5
step_b  = 1

for b in range(start_b, stop_b, step_b):
  make_closed_fig(plot, a=1, b=b, h=0, k=0, d=2, num_of_points=20)

plot.plot_funs(plot_title="Playing with b", img_name="frame1.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Make a video of drawing a face

# %%
# Playing with b

# Create a graph object with equal_axes)
plot = graph_funs(equal_axes=True, hide_axes=False)

# Setup the grid
# Determine the range for X based on reflections and translations.
# Determine the range for Y based on reflections and translations (look at maximum values).
plot.set_XY(minX=-10, maxX=+10, minY=0, maxY=+40)

# Draw different parts of the face and save in different frames

# Frame 1: draw the face:
make_closed_fig(plot, a=1, b=b, h=0, k=0, d=2, num_of_points=20)
plot.plot_funs(plot_title="Drawing the face", img_name="frame1.png")

# Frame 2: Draw the eyes:
make_closed_fig(plot, a=0.5, b=b, h=5, k=0, d=2, num_of_points=20)
make_closed_fig(plot, a=0.5, b=b, h=10, k=0, d=2, num_of_points=20)
plot.plot_funs(plot_title="Drawing the ...", img_name="frame2.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Make the drawing video
#
# 1. List all of the frames in img_list.
# 2. Give the duration in seconds how long you want each frame to appear.
# 3. Make your video.

# %%
# Create a video

# Decide which images and videos you want to put together:
img_list = ["frame1.png", "frame2.png"]

# Set the duration for each one in seconds.
durations_list = [2.0,   # duration for frame1.png
                  2.0]   # duration for frame2.png

# Create the video:
video=CreateVideo(video_name="all.mp4",       # This is file name of the final video.
                  file_list=img_list,         # This the list of images and files to combine.
                  fps=10,                     # The number of frames per second.
                  durations=durations_list)   # The duration for each one.

# Display the video:
video.ipython_display()
# Out:
# Opening  frame1.png
# Opening  frame2.png
# video: height =  500  width =  700
# The file 'all.mp4' will be created.
# VideoWriter initialized successfully.
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
