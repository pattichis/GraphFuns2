# %% [markdown]
# <a href="https://colab.research.google.com/github/pattichis/GraphFuns2/blob/main/Graphfuns_project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# The following code sets up the system by downloading the library from the web.

# %%
# Remove existing files
import os

VS_CODE = False # Set to True if using Visual Studio
if (not VS_CODE):
    # !pip install -U kaleido

    os.chdir("/content/")
    #!find './' -maxdepth 1 -type f -delete

    # Mount the drive:
    from google.colab import drive
    drive.mount('/content/drive')

    # Download the lineart library
    # !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/lineart_v3.py

    # Download the symbolic graphs library.
    # !wget 'https://raw.githubusercontent.com/pattichis/GraphFuns2/main/symbolic_graphs2.py'


# Import functions for creating videos
from lineart_v3 import table, simulationVideo, textImage, plotTablesLines, CreateVideo, changeVideoSpeed

# Import symbolic plotting functions
from symbolic_graphs2 import graph_funs
import numpy as np

# Import the library:
import sympy as sp

from sympy.interactive.printing import init_printing
init_printing()
# Out:
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.5 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1
# Mounted at /content/drive
# --2025-03-13 12:00:48--  https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/lineart_v3.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30381 (30K) [text/plain]
# Saving to: ‘lineart_v3.py’
#
# lineart_v3.py       100%[===================>]  29.67K  --.-KB/s    in 0.003s
#
# 2025-03-13 12:00:49 (8.48 MB/s) - ‘lineart_v3.py’ saved [30381/30381]
#
# --2025-03-13 12:00:49--  https://raw.githubusercontent.com/pattichis/GraphFuns2/main/symbolic_graphs2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16371 (16K) [text/plain]
# Saving to: ‘symbolic_graphs2.py’
#
# symbolic_graphs2.py 100%[===================>]  15.99K  --.-KB/s    in 0.001s
#
# 2025-03-13 12:00:49 (10.8 MB/s) - ‘symbolic_graphs2.py’ saved [16371/16371]
#
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':

# %% [markdown]
# # Make a beautiful flower
#
# 1. Make the first pedal look nice by reducing the domain.
# 2. Create the other pedals. Have fun coloring your pedals.
# 3. After you get the pedals, set hide_axes=True in graph_funs().
# 4. Remove plot.plot_funs() function calls to plot one pedal at a time only.
# 5. Save each pedal into a different picture.
#
# Here is a list of colors:
#    "blue", "green", "red", "cyan", "magenta", "yellow", "black", "white","olive","indigo".

# %%
def make_closed_fig(plot, a, b, h, k, d, num_of_points):
  """ Make a closed figure using:
       f(x)=a*b**(x-h)+k
  - a is a constant.
  - b is the base.
  - h is horizontal translation in (x-h).
  - k is vertical translation.
  Here, d is used to determine the domain: from -d to +d.
  num_of_points is the number of points to plot.
  plot specifies the plot object to plot on.
  The image is stored in img.
  """
  # Create the symbol
  x = sp.symbols('x')
  f0 = a*b**(x)+k

  # Specify mother function
  # Shift the domain by +h.
  f1 = f0.subs(x, x-h)
  domain1 = [0+h, d+h, num_of_points]

  # Invert it and move it up
  # Same domain.
  # Move f2 up
  f2 = -f1 + 2*f1.subs(x, d+h)
  domain2 = domain1

  # Reflect both:
  f3 = f0.subs(x, -x+h)
  domain3 = [h-d, 0+h, num_of_points]

  f4 = -f0.subs(x, -x+h) + 2*f3.subs(x, -d+h)
  domain4 = domain3

  plot.add_fun(f1, domain1, 'f1(x)='+str(f1), 'red')
  plot.add_fun(f2, domain2, 'f2(x)='+str(f2), 'blue')
  plot.add_fun(f3, domain3, 'f3(x)='+str(f3), 'green')
  plot.add_fun(f4, domain4, 'f4(x)='+str(f4), 'orange')



# Create a graph object with equal_axes)
plot = graph_funs(equal_axes=True, hide_axes=False)

# Setup the grid
# Determine the range for X based on reflections and translations.
# Determine the range for Y based on reflections and translations (look at maximum values).
plot.set_XY(minX=0, maxX=+25, minY=0, maxY=+25)

# Arithmetic series for x:
start_x = 5
stop_x  = 25
step_x  = 5

# Arithmetic series for y:
start_y = 5
stop_y  = 25
step_y  = 5

for x in range(start_x, stop_x, step_x):
  for y in range(start_y, stop_y, step_y):
    make_closed_fig(plot, a=2, b=2, h=x, k=y, d=1, num_of_points=20)

plot.plot_funs(plot_title="Closed figure", img_name="frame1.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="81ea7bf9-3678-4c04-b0a9-36032f878cd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81ea7bf9-3678-4c04-b0a9-36032f878cd6")) {                    Plotly.newPlot(                        "81ea7bf9-3678-4c04-b0a9-36032f878cd6",                        [{"line":{"color":"red"},"mode":"lines","name":"f1(x)=2*2^(x - 5) + 5","showlegend":true,"x":[5.0,5.052631578947368,5.105263157894737,5.157894736842105,5.2105263157894735,5.2631578947368425,5.315789473684211,5.368421052631579,5.421052631578947,5.473684210526316,5.526315789473684,5.578947368421053,5.631578947368421,5.684210526315789,5.7368421052631575,5.7894736842105265,5.842105263157895,5.894736842105263,5.947368421052632,6.0],"y":[7.0,7.074310088892384,7.151381172440365,7.2313158355230875,7.314220474565439,7.400205439156206,7.489385178928047,7.58187839589481,7.677808202448944,7.777302285229313,7.880493075077518,7.987517923308973,8.098519284533312,8.213644906267529,8.333048025594177,8.456887573126423,8.585328384551424,8.718541420033624,8.856703991769981,9.0],"type":"scatter"},{"line":{"color":"blue"},"mode":"lines","name":"f2(x)=13 - 2*2^(x - 5)","showlegend":true,"x":[5.0,5.052631578947368,5.105263157894737,5.157894736842105,5.2105263157894735,5.2631578947368425,5.315789473684211,5.368421052631579,5.421052631578947,5.473684210526316,5.526315789473684,5.578947368421053,5.631578947368421,5.684210526315789,5.7368421052631575,5.7894736842105265,5.842105263157895,5.894736842105263,5.947368421052632,6.0],"y":[11.0,10.925689911107616,10.848618827559635,10.768684164476912,10.685779525434562,10.599794560843794,10.510614821071954,10.41812160410519,10.322191797551056,10.222697714770687,10.119506924922483,10.012482076691027,9.901480715466688,9.786355093732471,9.666951974405823,9.543112426873577,9.414671615448576,9.281458579966376,9.143296008230019,9.0],"type":"scatter"},{"line":{"color":"green"},"mode":"lines","name":"f3(x)=2*2^(5 - x) + 5","showlegend":true,"x":[4.0,4.052631578947368,4.105263157894737,4.157894736842105,4.2105263157894735,4.2631578947368425,4.315789473684211,4.368421052631579,4.421052631578947,4.473684210526316,4.526315789473684,4.578947368421053,4.631578947368421,4.684210526315789,4.7368421052631575,4.7894736842105265,4.842105263157895,4.894736842105263,4.947368421052632,5.0],"y":[9.0,8.856703991769981,8.718541420033624,8.585328384551424,8.456887573126423,8.333048025594177,8.213644906267529,8.098519284533312,7.987517923308973,7.880493075077518,7.777302285229313,7.677808202448944,7.58187839589481,7.489385178928047,7.400205439156206,7.314220474565439,7.2313158355230875,7.151381172440365,7.074310088892384,7.0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"f4(x)=13 - 2*2^(5 - x)","showlegend":true,"x":[4.0,4.052631578947368,4.105263157894737,4.157894736842105,4.2105263157894735,4.2631578947368425,4.315789473684211,4.368421052631579,4.421052631578947,4.473684210526316,4.526315789473684,4.578947368421053,4.631578947368421,4.684210526315789,4.7368421052631575,4.7894736842105265,4.842105263157895,4.894736842105263,4.947368421052632,5.0],"y":[9.0,9.143296008230019,9.281458579966376,9.414671615448576,9.543112426873577,9.666951974405823,9.786355093732471,9.901480715466688,10.012482076691027,10.119506924922483,10.222697714770687,10.322191797551056,10.41812160410519,10.510614821071954,10.599794560843794,10.685779525434562,10.768684164476912,10.848618827559635,10.925689911107616,11.0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"f1(x)=2*2^(x - 5) + 10","showlegend":true,"x":[5.0,5.052631578947368,5.105263157894737,5.157894736842105,5.2105263157894735,5.2631578947368425,5.315789473684211,5.368421052631579,5.421052631578947,5.473684210526316, ...

# %% [markdown]
# # Make a video of your flower growing one pedal at a time
#
# 1. List all of the frames in img_list.
# 2. Give the duration in seconds how long you want each frame to appear.
# 3. Make your video.

# %%
# Create a video

# Decide which images and videos you want to put together:
img_list = ["frame1.png", "frame2.png", "frame3.png", "frame4.png"]

# Set the duration for each one in seconds.
durations_list = [2.0,   # duration for frame1.png
                  2.0,   # frame2.png
                  2.0,   # frame3.png
                  2.0]   # frame4.png

# Create the video:
video=CreateVideo(video_name="all.mp4",       # This is file name of the final video.
                  file_list=img_list,         # This the list of images and files to combine.
                  fps=10,                     # The number of frames per second.
                  durations=durations_list)   # The duration for each one.

# Display the video:
video.ipython_display()
# Out:
# Opening  frame1.png
# Opening  frame2.png
# Error: Could not open image: file name =  frame2.png
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-8c889c16cce4> in <cell line: 0>()
#      11
#      12 # Create the video:
# ---> 13 video=CreateVideo(video_name="all.mp4",       # This is file name of the final video.
#      14                   file_list=img_list,         # This the list of images and files to combine.
#      15                   fps=10,                     # The number of frames per second.
#
# /content/lineart_v3.py in CreateVideo(video_name, file_list, fps, durations)
#     698       if img is None:
#     699         print("Error: Could not open image: file name = ", filename)
# --> 700         raise ValueError("file name = "+filename+" cannot be opened!")
#     701
#     702       height, width, channels = img.shape
#
# ValueError: file name = frame2.png cannot be opened!
